# %%
#1. Install necessary libraries

import subprocess
subprocess.run(["pip", "install", "kagglehub", "--quiet"])
import kagglehub
import pandas as pd
import os
import numpy as np
import plotly.express as px
from matplotlib import pyplot as plt
# Out:
# StatementMeta(, 4fd132ee-4caa-4f65-8758-dcf9a6328b01, 3, Finished, Available, Finished, False)

# %%
# 2. Download dataset
path = kagglehub.dataset_download("sharmajicoder/gaming-and-mental-health")
print("Path to dataset files:", path)
# Out:
# StatementMeta(, 9e13d2f9-a67e-4096-9dc6-98897a4d3a69, 11, Finished, Available, Finished, False)
# Path to dataset files: /home/trusted-service-user/.cache/kagglehub/datasets/sharmajicoder/gaming-and-mental-health/versions/1

# %%
# 3. Configure pandas display settings
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = None
pd.options.display.max_columns = None
# Out:
# StatementMeta(, 9e13d2f9-a67e-4096-9dc6-98897a4d3a69, 12, Finished, Available, Finished, False)

# %%
# 4. Locate and load the primary CSV file
csv_file = [f for f in os.listdir(path) if f.endswith('.csv')][0]
full_path = os.path.join(path, csv_file)
df = pd.read_csv(full_path)
# Out:
# StatementMeta(, 9e13d2f9-a67e-4096-9dc6-98897a4d3a69, 13, Finished, Available, Finished, False)

# %%
# 5. Convert to a PySpark DataFrame
spark_df = spark.createDataFrame(df)
# Out:
# StatementMeta(, 9e13d2f9-a67e-4096-9dc6-98897a4d3a69, 14, Finished, Available, Finished, False)

# %%
#Data Info
df.info()
# Out:
# StatementMeta(, 9e13d2f9-a67e-4096-9dc6-98897a4d3a69, 15, Finished, Available, Finished, False)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   age                         1000000 non-null  int64
#  1   gender                      1000000 non-null  object
#  2   income                      1000000 non-null  int64
#  3   daily_gaming_hours          1000000 non-null  float64
#  4   weekly_sessions             1000000 non-null  int64
#  5   years_gaming                1000000 non-null  int64
#  6   sleep_hours                 1000000 non-null  float64
#  7   caffeine_intake             1000000 non-null  float64
#  8   exercise_hours              1000000 non-null  float64
#  9   stress_level                1000000 non-null  int64
#  10  anxiety_score               1000000 non-null  float64
# ...

# %%
#Data Description
df.describe()
# Out:
# StatementMeta(, 9e13d2f9-a67e-4096-9dc6-98897a4d3a69, 16, Finished, Available, Finished, False)
#                age       income  daily_gaming_hours  weekly_sessions  \
# count 1,000,000.00 1,000,000.00        1,000,000.00     1,000,000.00
# mean         35.99    77,497.68                4.00            20.00
# std          13.56    41,851.54                2.83            11.25
# min          13.00     5,000.00                0.00             1.00
# 25%          24.00    41,258.00                1.92            10.00
# 50%          36.00    77,521.00                3.36            20.00
# 75%          48.00   113,697.00                5.38            30.00
# max          59.00   149,999.00               30.42            39.00
#
#        years_gaming  sleep_hours  caffeine_intake  exercise_hours  \
# count  1,000,000.00 1,000,000.00     1,000,000.00    1,000,000.00
# mean          12.00         7.00             2.00            2.00
# ...

# %%
#Save data as Parquet in Bronze file
spark_df.write.mode("overwrite").format("parquet").save("Files/Bronze/Gaming_Bronze")
# Out:
# StatementMeta(, 9e13d2f9-a67e-4096-9dc6-98897a4d3a69, 17, Finished, Available, Finished, False)
